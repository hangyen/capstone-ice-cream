# %% [markdown]
# # Sugar Momma's Creamery
# Hang Nguyen | 11/14/2017

# %% [markdown]
# ### Goal:
#
# The goal of this project is to propose recommendations on how to open a successful ice cream shop. It will aim to answer the question:
#
# **What makes a great ice cream shop?**
#
# Using NLP techniques, we will look at reviews from the Foursquare API to create a model that can predict whether an ice cream is highly rated or not.
#
# ### Risks
# - Foursquare is a dated application
# - Not everyone writes reviews
# - What constitutes as a bad review? There might not be any bad reviews at all, doesn't give the whole picture
# - Not enough ice cream shops
# - Not enough reviews for a shop
#
# ### Hypothesis:
# - good/exciting flavors
# - good texture
# - fair pricing
# - fast and friendly customer service
#
# ### Data:
# - 163 stores around the country in major cities
# - 8,500 reviews from these stores from Foursquare
# - Rating from 5.7-9.5
#
# ### Assumptions:
# - Defining "great ice cream store" as stores with ratings that is in top 25% > 8.8
# - Defining "bad ice cream store" as stores with ratings that is in the bottom 25% < 7.3
#
# ### Investigate:
# - Of the data that we have, what's the split of reviews?
# - Are ratings influenced by # of users/#of tips? Looks like some relationship
# - Does each city have different standards of ratings?

# %%
import json, requests
import pandas as pd
import numpy as np
import regex as re

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import TruncatedSVD, LatentDirichletAllocation
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from nltk.corpus import stopwords
from sklearn.metrics import roc_curve, auc #area under curve
from wordcloud import WordCloud

# %% [markdown]
# # Getting the Data

# %% [markdown]
# ### Building the Location Table
#
# Using the Foursquare API, we pulled in the venue stats and wrote a few functions to help compile the table

# %%
#this function takes in an end point and a set of params and makes a request to 
def request_data(end_point, params):
    params = params
    resp = requests.get(url=end_point, params=params)
    data = json.loads(resp.text)
    print(end_point)
    return data

# %%
#this is a function that formats the data by putting it into a list of dictionaries. 
def make_location_table(data):

    lst = []
    
    for each in range(len(data['response']['venues'])):
        dct = {}
        dct['venue_id'] = data['response']['venues'][each]['id']
        dct['name'] = data['response']['venues'][each]['name']
        dct['total_checkins'] = data['response']['venues'][each]['stats']['checkinsCount']
        dct['total_users'] = data['response']['venues'][each]['stats']['usersCount']
        dct['tip_count'] = data['response']['venues'][each]['stats']['tipCount']

        try:
            dct['address'] = data['response']['venues'][each]['location']['address']
        except:
            dct['address'] = 'None'

        try:
            dct['city'] = data['response']['venues'][each]['location']['city']
        except:
            dct['city'] = None

        try:
            dct['state'] = data['response']['venues'][each]['location']['state']
        except:
            dct['city'] = None    
            
        try:   
            dct['zipcode'] = data['response']['venues'][each]['location']['postalCode']
        except:
            dct['zipcode'] = 'None'

        try:
            dct['lat'] = data['response']['venues'][each]['location']['lat']
        except:
            dct['lat'] = 'None'

        try:
            dct['long'] = data['response']['venues'][each]['location']['lng']
        except:
            dct['long'] = 'None'

        lst.append(dct)

    new_df = pd.DataFrame(lst, columns = ['venue_id', 'name', 'address', 'city', 'state', 
                                               'zipcode', 'lat', 'long', 'total_checkins',
                                               'total_users', 'tip_count'])
    return new_df

# %%
client_id = 'WJZHVEFVUBTJ1XO42NH5GKWBFV2OQG0JQ11SYKBPRGX5I1BN'
client_secret ='2V3GYPYAK5BMS4NLSWZLTGL2IEZ51524J1CQDHW5ME1DXQUN'

search_endpoint = 'https://api.foursquare.com/v2/venues/search'

location_table = pd.DataFrame()

near = [
    'New York, NY',
    'Brooklyn, NY',
    'Harlem, NY',
    'Lower East Side, NY',
    'East Village, NY',
    'Greenwich Village, NY',
    'Brooklyn Heights, NY',
    'Soho, NY', 
    'San Francisco, CA',
    'Soma, CA',
    'Mission District, San Francisco',
    'Los Angeles, CA',
    'Santa Monica, CA',
    'Hollywood, CA', 
    'Portland, OR',   
    'Oakland, CA', 
    'Berkeley, CA',  
    'Long Beach, CA', 
    'Seattle, WA',     
    'Boston, MA',
    'Jamaica Plain, MA',
    'Brookline, MA',
    'Cambridge, MA',
    'Austin, TX'
]


for location in near:
    search_params = dict(
        client_id=client_id,
        client_secret=client_secret,
        v='20171114',
        near = location,
        query='ice cream',
        limit=50,
        intent = 'browse')
    data = request_data(search_endpoint, search_params)
    new_df = make_location_table(data)
    location_table = pd.concat([location_table, new_df], axis =0, ignore_index = True)
# Out:
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search
# https://api.foursquare.com/v2/venues/search

# %%
#clean the dataframe:
#remove duplicate venues in table
location_table = location_table.drop_duplicates(subset= 'venue_id', keep = 'first')

# %%
#drop rows where number of tips = 0 and checkins = 0
location_table = location_table[(location_table['tip_count'] != 0) 
                                & (location_table['total_checkins'] != 0) ]

# %%
#there are a bunch of places that shouldn't be on here:

remove_indexes = \
            location_table.name[location_table.name.str.contains(
                    "Ice [Ss]kating|Ice [Rr]ink|[Ss][haved]|Hockey|Icebreaker|Arena|Museum|Disney|NBC|\
                Union Square|Fish|Slush|Italian Ice|Center|Oakland Ice Center|Waterloo|Ice Kingdom|Cybelle|Lounge|\
                Cupcake|Grocery|[Ff][iI][Rr][Ee] [&+] [Ii][Cc][Ee]|Picco|Quincy|Angora|Social Bus|Water-Ice|Chaparral")].index

location_table.drop(remove_indexes, axis =0, inplace = True)

# %%
#construct the venue id list from location_table
venue_ids_lst = location_table['venue_id']
# Play J Ice Cream Truck
# Polly Ann Ice Cream
# Post Street Creamery
# Post Street Creamery
# Roll Up Creamery & Cafe
# Ron's Gourmet Ice Cream and 20th Century Bowling
# Ruby Jewel Scoops
# Smitten Ice Cream
# Smitten Ice Cream
# Smitten Ice Cream
# Smitten Ice Cream
# Smitten Ice Cream
# Snowy Joey's Ice Cream Truck
# Soft Ice Cream Truck
# Soft Swerve Ice Cream
# Sprinkles Ice Cream
# Sprinkles Ice Cream
# Sprinkles Ice Cream
# Spumoni Authentic Italian Creamery
# Spun Ice Cream
# Spun Ice Cream
# Stax Ice Cream
# Steep Creamery
# Strauss Soft Ice Cream
# Stuffed Ice Cream
# Sugar Hill Creamery
# Sweet Alchemy Ice Cream
# Süsu rolled ice cream
# Tara's Organic Ice Cream
# Tara’s Organic Ice Cream
# Tartine Cookies & Cream
# The Creamery
# The Ice Box
# The Ice Box at Fornino
# The Ice Cream Bar Soda Fountain
# The Ice Creamsmith
# The Original Chinatown Ice Cream Factory 華埠雪糕行 (The Original Chinatown Ice Cream Factory)
# Three Twins Ice Cream
# Three Twins Organic Ice Cream
# Toscanini's
# Treats Frozen Yogurt & Ice Bar
# Uber Ice Cream Truck
# Umpqua Ice Cream
# Van Leeuwen Ice Cream Truck - 23rd
# Van Leeuwen Ice Cream Truck - 29th
# Van Leeuwen Ice Cream Truck - 6th
# Van Leeuwen Ice Cream Truck - Bedford
# Van Leeuwen Ice Cream Truck - Bleecker
# Van Leeuwen Ice Cream Truck - Greene
# Wai's Restaurant
# Xanath Ice Cream
# YoCream Frozen Yogurt
# Zero Degrees Ice Cream Creations
# Zero Degrees Ice Cream Creations (inside H-E-B)
# iCrossing Ice Cream Social
# 泰芒了 Justin Tea Inc - 196° Ice Cream

# %% [markdown]
# ### Building the vendor rating table

# %%
rating_params = dict(
  client_id=client_id,
  client_secret=client_secret,
  v='20171114')

# %%
ratings_lst = []
for venue_id in venue_ids_lst:
    rating_endpoint = 'https://api.foursquare.com/v2/venues/{}'.format(venue_id)
    data = request_data(rating_endpoint, rating_params)
    #make the dictionary
    dct = {}
    try:
        dct['name'] = data['response']['venue']['name']
    except:
        dct['name'] = None

    dct['venue_id'] = data['response']['venue']['id']
    
    try:
        dct['rating'] = data['response']['venue']['rating']
    except:
        dct['rating'] = None
    
    #append to ratings list
    ratings_lst.append(dct)
    
#turn list of dicts into df
ratings_table = pd.DataFrame(ratings_lst, columns = ['venue_id', 'name', 'rating'])
# Out:
# https://api.foursquare.com/v2/venues/537cd1bb498e956dc853b6a4
# https://api.foursquare.com/v2/venues/3fd66200f964a52033eb1ee3
# https://api.foursquare.com/v2/venues/4c8e2f1e1664b1f7580c9e2f
# https://api.foursquare.com/v2/venues/4cc07b8900d8370444e24a5c
# https://api.foursquare.com/v2/venues/518ad7d1454aeee512a0f518
# https://api.foursquare.com/v2/venues/56db5ad2498e66632d8adbec
# https://api.foursquare.com/v2/venues/5780775a498eb55b2973ce2c
# https://api.foursquare.com/v2/venues/4da9e90da86e771ea7178471
# https://api.foursquare.com/v2/venues/49f3daf9f964a520e86a1fe3
# https://api.foursquare.com/v2/venues/55877ae9498ee57015ef8d23
# https://api.foursquare.com/v2/venues/5973b09eb9ac383dd3d1ec85
# https://api.foursquare.com/v2/venues/582dce98fd27163e8350257f
# https://api.foursquare.com/v2/venues/4a50f27ef964a5204bb01fe3
# https://api.foursquare.com/v2/venues/571d2ced498e590d68ee74ae
# https://api.foursquare.com/v2/venues/576f2c3c498e0917af14bc65
# https://api.foursquare.com/v2/venues/4d977255c19fb60c42179765
# https://api.foursquare.com/v2/venues/4bd0d9a2462cb7134f40d907
# https://api.foursquare.com/v2/venues/57c2080a498e1bdf3cc66019
# https://api.foursquare.com/v2/venues/537803a0498ef1607aafd28b
# https://api.foursquare.com/v2/venues/4dcdd3fae4cd130e16586c20
# https://api.foursquare.com/v2/venues/4c7979d8a868370436c7104d
# https://api.foursquare.com/v2/venues/4fcbdcaae4b00a0e855124dd
# https://api.foursquare.com/v2/venues/4f88bb85e4b0af04bfe61aa4
# https://api.foursquare.com/v2/venues/59ac838a5161136b7746660f
# https://api.foursquare.com/v2/venues/5359898111d27f2c30969a1c
# https://api.foursquare.com/v2/venues/4e46ec56b61c03d0cd131d73
# https://api.foursquare.com/v2/venues/4a6fa830f964a520bad61fe3
# https://api.foursquare.com/v2/venues/4abd01bbf964a5200a8820e3
# https://api.foursquare.com/v2/venues/4b3f7adcf964a5208fa725e3
# https://api.foursquare.com/v2/venues/4bf4b51e6a31d13ab025962e
# https://api.foursquare.com/v2/venues/518a87b3454aef48b51a84ce
# https://api.foursquare.com/v2/venues/4baac398f964a52040853ae3
# https://api.foursquare.com/v2/venues/4bb1338ef964a520f0823ce3
# https://api.foursquare.com/v2/venues/509aaaa46ebbda87a3c403ea
# https://api.foursquare.com/v2/venues/465c3714f964a5202f471fe3
# https://api.foursquare.com/v2/venues/553bf653498eba55ec0bdfde
# https://api.foursquare.com/v2/venues/589800799398ab157abb6fba
# https://api.foursquare.com/v2/venues/57252fc6498e11c981242555
# https://api.foursquare.com/v2/venues/567a07e3498ea3d07b6a8a8f
# https://api.foursquare.com/v2/venues/4bb946b253649c747eea47fb
# https://api.foursquare.com/v2/venues/592f74d91f8ed6677f615758
# https://api.foursquare.com/v2/venues/4da759dbfa8c4175d09fd01a
# https://api.foursquare.com/v2/venues/56d88820498effe63b065027
# https://api.foursquare.com/v2/venues/4a63840bf964a5203ac51fe3
# https://api.foursquare.com/v2/venues/4e06cd92d4c03ae0b9c66dee
# https://api.foursquare.com/v2/venues/597bceff898bdc5ce51bfc3d
# https://api.foursquare.com/v2/venues/4c5f49c8b36eb713a11793d2
# https://api.foursquare.com/v2/venues/592a4043c21cb17f349bedc4
# https://api.foursquare.com/v2/venues/591b3644ca18ea6893b76199
# https://api.foursquare.com/v2/venues/5803e07238fad71ff49a754e
# https://api.foursquare.com/v2/venues/4e9c7c8493ada5036e20bcec
# https://api.foursquare.com/v2/venues/591ba2b628374e44f1bd1a47
# https://api.foursquare.com/v2/venues/4e2cad83ae605c533a453da4
# https://api.foursquare.com/v2/venues/5592f04e498ec2ba8088da24
# https://api.foursquare.com/v2/venues/4c4c8d02c8b6b713d8de8ffb
# https://api.foursquare.com/v2/venues/590a00e74febd55af43a8267
# https://api.foursquare.com/v2/venues/57113f5b498e057aaa17ae87
# https://api.foursquare.com/v2/venues/4ad7bc24f964a520430e21e3
# https://api.foursquare.com/v2/venues/4e459fbf183849317e6b0ead
# https://api.foursquare.com/v2/venues/4ab95c9ef964a520167f20e3
# https://api.foursquare.com/v2/venues/4c0bc7c8009a0f47678debbf
# https://api.foursquare.com/v2/venues/4fe51517e4b0972a1cb0b85c
# https://api.foursquare.com/v2/venues/49bf289bf964a5200a551fe3
# https://api.foursquare.com/v2/venues/3fd66200f964a52018e71ee3
# https://api.foursquare.com/v2/venues/55c29918498ecf4c88aae8ae
# https://api.foursquare.com/v2/venues/4ad8b2f3f964a520cf1321e3
# https://api.foursquare.com/v2/venues/572b4f1b498e845e04f9628c
# https://api.foursquare.com/v2/venues/5990ae0dff190235c73cc6ff
# https://api.foursquare.com/v2/venues/4c1406b477cea59321f3cf60
# https://api.foursquare.com/v2/venues/4c3a5ad83849c92880e0c2b1
# https://api.foursquare.com/v2/venues/43504680f964a520b2281fe3
# https://api.foursquare.com/v2/venues/5206aaa211d21900dca3789a
# https://api.foursquare.com/v2/venues/4ee6989f775ba356dfd04962
# https://api.foursquare.com/v2/venues/517abbd7e4b0de63518cb59e
# https://api.foursquare.com/v2/venues/4d964291daec224b08b9123e
# https://api.foursquare.com/v2/venues/58d1d4f40b7e9334921a33fd
# https://api.foursquare.com/v2/venues/4a36e532f964a520fb9d1fe3
# https://api.foursquare.com/v2/venues/4eac41a5dab40d132703fc44
# https://api.foursquare.com/v2/venues/49e22ce6f964a520f9611fe3
# https://api.foursquare.com/v2/venues/5580cf64498e02a81bc0e87d
# https://api.foursquare.com/v2/venues/572bb0c7cd10e413c26cda5e
# https://api.foursquare.com/v2/venues/52cc9c4a498e154112bd1718
# https://api.foursquare.com/v2/venues/4a039807f964a520d1711fe3
# https://api.foursquare.com/v2/venues/53fba1eb498e5054f6863edb
# https://api.foursquare.com/v2/venues/49f5fab6f964a520e26b1fe3
# https://api.foursquare.com/v2/venues/57784c4b498e532e84e77f3f
# https://api.foursquare.com/v2/venues/5945765f4382ab30b2681d60
# https://api.foursquare.com/v2/venues/4bb7d9273db7b71353aa209a
# https://api.foursquare.com/v2/venues/4c539eb5728920a130a96181
# https://api.foursquare.com/v2/venues/527fff66498e7b9ac457533e
# https://api.foursquare.com/v2/venues/58cc88f1e0adac0132aaade3
# https://api.foursquare.com/v2/venues/50317830e4b0c65b4bd6caab
# https://api.foursquare.com/v2/venues/4f348657e4b03c36f8d8c764
# https://api.foursquare.com/v2/venues/4ac7cb2af964a520ccb920e3
# https://api.foursquare.com/v2/venues/49ba70ecf964a52063531fe3
# https://api.foursquare.com/v2/venues/446dcedaf964a5206b331fe3
# https://api.foursquare.com/v2/venues/58d0586b790bea304c79a11a
# https://api.foursquare.com/v2/venues/51cdef0a498e0f0c9f3f9f03
# https://api.foursquare.com/v2/venues/5344c5eb498e30bf05946233
# https://api.foursquare.com/v2/venues/45eaff58f964a5208e431fe3
# https://api.foursquare.com/v2/venues/49972b39f964a52089521fe3
# https://api.foursquare.com/v2/venues/53d7c8ad498efad6b858679e
# https://api.foursquare.com/v2/venues/580bd3e338fafba1f0fe7ca8
# https://api.foursquare.com/v2/venues/589d125b005a0f47b970b12b
# https://api.foursquare.com/v2/venues/596bfeb1c9a51768ce0d1849
# https://api.foursquare.com/v2/venues/4bca5fc5511f9521eebfafc7
# https://api.foursquare.com/v2/venues/54f934f0498e035356a088e8
# https://api.foursquare.com/v2/venues/575cab45498e32bff9f4208b
# https://api.foursquare.com/v2/venues/53d67d2c498ebc39aab217fc
# https://api.foursquare.com/v2/venues/4a567722f964a52037b51fe3
# https://api.foursquare.com/v2/venues/4fbe82f7e4b0f42520ae5189
# https://api.foursquare.com/v2/venues/588a7ad745005e3255761ba2
# https://api.foursquare.com/v2/venues/4b536cbcf964a520699c27e3
# https://api.foursquare.com/v2/venues/4b73aab8f964a520cab72de3
# https://api.foursquare.com/v2/venues/5522a0c9498e1d3a868b3412
# https://api.foursquare.com/v2/venues/4b9992d0f964a520ac8435e3
# https://api.foursquare.com/v2/venues/59a5c29d6f0aa21694c44506
# https://api.foursquare.com/v2/venues/50f84f1252629ece46dfa742
# https://api.foursquare.com/v2/venues/583f99cb730a921386173b92
# https://api.foursquare.com/v2/venues/4ada0fc9f964a520eb1d21e3
# https://api.foursquare.com/v2/venues/56e50366498eaca0d0dfec6e
# https://api.foursquare.com/v2/venues/4bf0850e3a15d13abcad3e9f
# https://api.foursquare.com/v2/venues/4bd9ea22c79cc9281d9d7ce9
# https://api.foursquare.com/v2/venues/4b64c29bf964a52001ce2ae3
# https://api.foursquare.com/v2/venues/4c5c80b67735c9b6077a8c72
# https://api.foursquare.com/v2/venues/5983f3bfb9a5a866d5bc5777
# https://api.foursquare.com/v2/venues/539a753c498e2365d2956825
# https://api.foursquare.com/v2/venues/4bba6a023db7b713e547239a
# https://api.foursquare.com/v2/venues/4a48558cf964a520b2aa1fe3
# https://api.foursquare.com/v2/venues/4fa5a772e4b09d4d45c94196
# https://api.foursquare.com/v2/venues/4dd880441f6ee146833ec204
# https://api.foursquare.com/v2/venues/50bbd0ade4b06d86dae87b8e
# https://api.foursquare.com/v2/venues/563bead9cd1017136920dc66
# https://api.foursquare.com/v2/venues/4b58cf91f964a520566c28e3
# https://api.foursquare.com/v2/venues/4f238286e4b0b653a2a28b55
# https://api.foursquare.com/v2/venues/4d8166c01ec4224b83b7c792
# https://api.foursquare.com/v2/venues/4bc963df511f9521cfbaadc7
# https://api.foursquare.com/v2/venues/4c4c9d3ca34b2d7f7211fd97
# https://api.foursquare.com/v2/venues/58dc3cb5e9233e27bf363309
# https://api.foursquare.com/v2/venues/4be1cd55a145c928cc9f4e80
# https://api.foursquare.com/v2/venues/4a60f584f964a5208dc11fe3
# https://api.foursquare.com/v2/venues/4a64ac65f964a52073c61fe3
# https://api.foursquare.com/v2/venues/4fa8896ae4b08ab44f9c353c
# https://api.foursquare.com/v2/venues/4f4aba4ce4b007d3911e020a
# https://api.foursquare.com/v2/venues/55adc93b498e2f5da4d33f30
# https://api.foursquare.com/v2/venues/55ff3220498ed5a54508d4ea
# https://api.foursquare.com/v2/venues/4ab843bcf964a520c67c20e3
# https://api.foursquare.com/v2/venues/4c253d50b012b7139fa60893
# https://api.foursquare.com/v2/venues/4aac3297f964a520cf5c20e3
# https://api.foursquare.com/v2/venues/4a6b8638f964a520face1fe3
# https://api.foursquare.com/v2/venues/4d98fbf6e07ea35dbe7fff02
# https://api.foursquare.com/v2/venues/4a3f0c0bf964a520aaa31fe3
# https://api.foursquare.com/v2/venues/49ed6552f964a520e9671fe3
# https://api.foursquare.com/v2/venues/4d79a0d00ceba1cd5d1ab558
# https://api.foursquare.com/v2/venues/55c5510a498e07f0bd6ec865
# https://api.foursquare.com/v2/venues/4a357b76f964a5200a9d1fe3
# https://api.foursquare.com/v2/venues/49fe6217f964a5209d6f1fe3
# https://api.foursquare.com/v2/venues/46918242f964a520ad481fe3
# https://api.foursquare.com/v2/venues/5316705c498ecb2239e69fc1
# https://api.foursquare.com/v2/venues/4bbc1758e5b0d13a53f36e7c
# https://api.foursquare.com/v2/venues/4c159fb0a1010f477f654e18
# https://api.foursquare.com/v2/venues/4b9943f4f964a520b86e35e3
# https://api.foursquare.com/v2/venues/574e695d498e8314519222e5
# https://api.foursquare.com/v2/venues/463c53f3f964a5202d461fe3
# https://api.foursquare.com/v2/venues/48175dc5f964a520674f1fe3
# https://api.foursquare.com/v2/venues/4b009a2df964a520e03f22e3
# https://api.foursquare.com/v2/venues/5562503e498e30fbab71994a
# https://api.foursquare.com/v2/venues/57213571498e0718cd926737
# https://api.foursquare.com/v2/venues/57f19414498e64984d440477
# https://api.foursquare.com/v2/venues/59112b2995d9860958a34250
# https://api.foursquare.com/v2/venues/51d77969498ebf3e103c1e6f
# https://api.foursquare.com/v2/venues/4a8a198ff964a520e00920e3
# https://api.foursquare.com/v2/venues/58e1377bd772f9415f28c247
# https://api.foursquare.com/v2/venues/4d0d9c6e3bbaa1430d373eda
# https://api.foursquare.com/v2/venues/4bf8381a5ec320a1135f88d3
# https://api.foursquare.com/v2/venues/55c46157498e9438593ea7c7
# https://api.foursquare.com/v2/venues/4e90d8028b81c6df65e0433b
# https://api.foursquare.com/v2/venues/4c0d85d4336220a1fae2ca77
# https://api.foursquare.com/v2/venues/4e3411a588772aabd8b30a70
# https://api.foursquare.com/v2/venues/4b6f630af964a5205aee2ce3
# https://api.foursquare.com/v2/venues/4d2cf61a1c5f2d4311a8fcb0
# https://api.foursquare.com/v2/venues/4b1477e8f964a5207ea323e3
# https://api.foursquare.com/v2/venues/544f146d498e56fb6c2231ec
# https://api.foursquare.com/v2/venues/555906f0498e63ff8da0af72
# https://api.foursquare.com/v2/venues/4c27ea7697d00f47a0283fea
# https://api.foursquare.com/v2/venues/49f3a8b6f964a520d06a1fe3
# https://api.foursquare.com/v2/venues/4a661356f964a520f4c71fe3
# https://api.foursquare.com/v2/venues/4dc484e9d164eb9c9fd7ee51
# https://api.foursquare.com/v2/venues/4eb46445722e578a4efe4694
# https://api.foursquare.com/v2/venues/49b84ec4f964a5203f531fe3
# https://api.foursquare.com/v2/venues/527ead51498e9cdc232bc428
# https://api.foursquare.com/v2/venues/4b09e2d8f964a520301f23e3
# https://api.foursquare.com/v2/venues/584daf054287c956a213e267
# https://api.foursquare.com/v2/venues/4b459db3f964a520950e26e3
# https://api.foursquare.com/v2/venues/485e50d9f964a520d6501fe3
# https://api.foursquare.com/v2/venues/4e72a7202271391c7002bb5e
# https://api.foursquare.com/v2/venues/57af82c1498e28aefe1a46d0
# https://api.foursquare.com/v2/venues/4ddc3177d22df17198f97a2b
# https://api.foursquare.com/v2/venues/56be08c8498e44ed4192b559
# https://api.foursquare.com/v2/venues/5000742ce4b0c123dd09fe1a
# https://api.foursquare.com/v2/venues/4be730c7cf200f479165153c
# https://api.foursquare.com/v2/venues/4e0fb79422711665f621aa33
# https://api.foursquare.com/v2/venues/4e0bce011838d77f46f3ac8b
# https://api.foursquare.com/v2/venues/53af49f8498ee976142682e3
# https://api.foursquare.com/v2/venues/4c5369eb72cf0f47937ecbd2
# https://api.foursquare.com/v2/venues/4a468425f964a52000a91fe3
# https://api.foursquare.com/v2/venues/4fc95853e4b092e3b94a2f4f
# https://api.foursquare.com/v2/venues/4ba51a0df964a52065dd38e3
# https://api.foursquare.com/v2/venues/4f6a5b7ee4b03571235d827c
# https://api.foursquare.com/v2/venues/4bccac10cc8cd13a6e5cc1cf
# https://api.foursquare.com/v2/venues/4c4c6d0746240f4762a1c7f4
# https://api.foursquare.com/v2/venues/4a62196df964a5201ac31fe3
# https://api.foursquare.com/v2/venues/4dc6e80ed4c0ad9c0fac8cd0
# https://api.foursquare.com/v2/venues/57b8776f498ed37ee6150835
# https://api.foursquare.com/v2/venues/4e3ae5172271ead2c0f5da3e
# https://api.foursquare.com/v2/venues/4a72f6a4f964a52060db1fe3
# https://api.foursquare.com/v2/venues/4b759b72f964a52032172ee3
# https://api.foursquare.com/v2/venues/4e4acf1bb0fb37342ef3f2d3
# https://api.foursquare.com/v2/venues/4fe3c29ae4b0ee8c45f27983
# https://api.foursquare.com/v2/venues/4a9453d1f964a5203d2120e3
# https://api.foursquare.com/v2/venues/4f9b59bae4b04dd734c0b31c
# https://api.foursquare.com/v2/venues/40b28c80f964a5200bf81ee3
# https://api.foursquare.com/v2/venues/4c530479b6dabe9a31f32114
# https://api.foursquare.com/v2/venues/511ff09ce4b0655fee51b12d
# https://api.foursquare.com/v2/venues/4b05e4cff964a52045e522e3
# https://api.foursquare.com/v2/venues/412d2800f964a520c90c1fe3
# https://api.foursquare.com/v2/venues/4aea412bf964a5208aba21e3
# https://api.foursquare.com/v2/venues/4b48cb50f964a520495726e3
# https://api.foursquare.com/v2/venues/4dd6d669c65bee535aa34b1d
# https://api.foursquare.com/v2/venues/4f326b4c19836c91c7d5f75f
# https://api.foursquare.com/v2/venues/42853f80f964a520f7221fe3
# https://api.foursquare.com/v2/venues/4a6ce03bf964a520e5d11fe3
# https://api.foursquare.com/v2/venues/49dcddddf964a520b35f1fe3
# https://api.foursquare.com/v2/venues/4aa5a2d1f964a520084920e3
# https://api.foursquare.com/v2/venues/524608b211d214ad05e42b43
# https://api.foursquare.com/v2/venues/53a742a5498ecd1a94893b9f
# https://api.foursquare.com/v2/venues/43388b80f964a52031281fe3
# https://api.foursquare.com/v2/venues/49cd30d4f964a520ca591fe3
# https://api.foursquare.com/v2/venues/4ac95679f964a520b3bf20e3
# https://api.foursquare.com/v2/venues/57ec6f49498ed271e121a819
# https://api.foursquare.com/v2/venues/4a078354f964a52077731fe3
# https://api.foursquare.com/v2/venues/566f6460498e99280bc37325
# https://api.foursquare.com/v2/venues/4a11df1af964a52056771fe3
# https://api.foursquare.com/v2/venues/49c9af8ef964a52090581fe3
# https://api.foursquare.com/v2/venues/4e53dc3b8877863330a7db6b
# https://api.foursquare.com/v2/venues/4a20c042f964a520bf7c1fe3
# https://api.foursquare.com/v2/venues/49bee6d5f964a520f2541fe3
# https://api.foursquare.com/v2/venues/53d1b1d7498eeecf573fef9a
# https://api.foursquare.com/v2/venues/4e9cb24446904f8f933fc63b
# https://api.foursquare.com/v2/venues/4a639ce4f964a52073c51fe3
# https://api.foursquare.com/v2/venues/55aed676498ea88a0e5564d7
# https://api.foursquare.com/v2/venues/4a346d9bf964a5203f9c1fe3
# https://api.foursquare.com/v2/venues/52422e69498e75d8a0025c58
# https://api.foursquare.com/v2/venues/4b79ec82f964a520921a2fe3
# https://api.foursquare.com/v2/venues/49c6b109f964a52070571fe3
# https://api.foursquare.com/v2/venues/4dfe882dd16411d11c5beaa9
# https://api.foursquare.com/v2/venues/5977d93b4acb1904af19fd2c
# https://api.foursquare.com/v2/venues/4bf33112e5eba593be511e90
# https://api.foursquare.com/v2/venues/4cb24d7ededbef3b5e209d40
# https://api.foursquare.com/v2/venues/4aa7cb0ef964a5203b4d20e3
# https://api.foursquare.com/v2/venues/4cf70303dc40a35dcf5e4b54
# https://api.foursquare.com/v2/venues/557252af498ee891b8e13db7
# https://api.foursquare.com/v2/venues/566ded46498eba26c63d7524
# https://api.foursquare.com/v2/venues/56f1dc0c498ebd3115325b97
# https://api.foursquare.com/v2/venues/4c5df1b52815c928666cb667

# %%
ratings_table.head()
# Out:
#                    venue_id  \
# 0  537cd1bb498e956dc853b6a4
# 1  3fd66200f964a52033eb1ee3
# 2  4c8e2f1e1664b1f7580c9e2f
# 3  4cc07b8900d8370444e24a5c
# 4  518ad7d1454aeee512a0f518
#
#                                                 name  rating
# 0                     Morgenstern's Finest Ice Cream     9.1
# 1  The Original Chinatown Ice Cream Factory 華埠雪糕行...     9.2
# 2                  Van Leeuwen Ice Cream Truck - 6th     7.2
# 3                 Van Leeuwen Ice Cream Truck - 23rd     NaN
# 4                                  Davey's Ice Cream     9.2

# %%
#concat location table with ratings table
df = location_table.merge(ratings_table, on='venue_id', how='inner', suffixes=('_1', '_2'))
df.drop("name_2", inplace=True, axis = 1)

# %%
df.head()
# Out:
#                    venue_id  \
# 0  537cd1bb498e956dc853b6a4
# 1  3fd66200f964a52033eb1ee3
# 2  4c8e2f1e1664b1f7580c9e2f
# 3  4cc07b8900d8370444e24a5c
# 4  518ad7d1454aeee512a0f518
#
#                                               name_1         address  \
# 0                     Morgenstern's Finest Ice Cream  2 Rivington St
# 1  The Original Chinatown Ice Cream Factory 華埠雪糕行...    65 Bayard St
# 2                  Van Leeuwen Ice Cream Truck - 6th        6th Ave.
# 3                 Van Leeuwen Ice Cream Truck - 23rd        23rd St.
# 4                                  Davey's Ice Cream     137 1st Ave
#
#        city state zipcode        lat       long  total_checkins  total_users  \
# 0  New York    NY   10002  40.721597 -73.993160           13510         7988
# 1  New York    NY   10013  40.715599 -73.998202           21856        13677
# 2  New York    NY   10010  40.742337 -73.993279             446          175
# 3  New York    NY    None  40.741761 -73.988555             564          335
# 4  New York    NY   10003  40.727839 -73.985173            6939         4003
#
#    tip_count  rating
# 0        401     9.1
# 1        431     9.2
# 2          4     7.2
# 3          7     NaN
# 4        154     9.2

# %%
df.rename(columns ={"name_1": "name"}, inplace = True)

# %%
df = df[~df.rating.isnull()]

# %%
#let's clean up that one last null
df.loc[df[df.city.isnull()].index,'city'] = 'Los Angeles'
df.isnull().sum()
# Out:
# venue_id          0
# name              0
# address           0
# city              0
# state             0
# zipcode           0
# lat               0
# long              0
# total_checkins    0
# total_users       0
# tip_count         0
# rating            0
# dtype: int64

# %%
df['state'] = df['state'].replace(to_replace = "California", value = "CA")
df.state.value_counts()
# Out:
# CA    72
# NY    52
# MA    22
# TX    17
# WA    16
# OR     8
# Name: state, dtype: int64

# %%
#drop that Fire & Ice bs!!!
df = df.drop(df[df.name.str.contains('FiRE')].index, axis =0)

# %% [markdown]
# ### Building the Tips Table:

# %%
tips_params = dict(
  client_id=client_id,
  client_secret=client_secret,
  v='20171114', limit = 500)

#reset venue list:
venue_ids_lst = df['venue_id']
venue_ids_lst.shape
# Out:
# (186,)

# %%
#make function that builds tips tables
def make_tips_table(data, venue_id):
    lst = []
 
    for tip in range(len(data['response']['tips']['items'])):
        dct = {}
        dct['venue_id'] = venue_id
        dct['tip_id'] = data['response']['tips']['items'][tip]['id']
        
        #Seconds since epoch when their tip was created.
        dct['created_date'] = data['response']['tips']['items'][tip]['createdAt']
        dct['agree_count'] = data['response']['tips']['items'][tip]['agreeCount']
        dct['disagree_count'] = data['response']['tips']['items'][tip]['disagreeCount']
        dct['user_gender'] = data['response']['tips']['items'][tip]['user']['gender']
        dct['tip_text'] = data['response']['tips']['items'][tip]['text']

        lst.append(dct)

    new_df = pd.DataFrame(lst, columns = ['venue_id','tip_id', 'created_date', 'agree_count', 'disagree_count',
                                              'user_gender', 'tip_text'])
        
    return new_df

# %%
#create venue ids lst

tips_table = pd.DataFrame()

for venue_id in venue_ids_lst:
    tips_endpoint = 'https://api.foursquare.com/v2/venues/{}/tips'.format(venue_id)
    data = request_data(tips_endpoint, tips_params)
    new_df = make_tips_table(data, venue_id)
    tips_table = pd.concat([tips_table, new_df], axis = 0, ignore_index=False)
# Out:
# https://api.foursquare.com/v2/venues/537cd1bb498e956dc853b6a4/tips
# https://api.foursquare.com/v2/venues/3fd66200f964a52033eb1ee3/tips
# https://api.foursquare.com/v2/venues/4c8e2f1e1664b1f7580c9e2f/tips
# https://api.foursquare.com/v2/venues/518ad7d1454aeee512a0f518/tips
# https://api.foursquare.com/v2/venues/56db5ad2498e66632d8adbec/tips
# https://api.foursquare.com/v2/venues/5780775a498eb55b2973ce2c/tips
# https://api.foursquare.com/v2/venues/4da9e90da86e771ea7178471/tips
# https://api.foursquare.com/v2/venues/49f3daf9f964a520e86a1fe3/tips
# https://api.foursquare.com/v2/venues/55877ae9498ee57015ef8d23/tips
# https://api.foursquare.com/v2/venues/5973b09eb9ac383dd3d1ec85/tips
# https://api.foursquare.com/v2/venues/582dce98fd27163e8350257f/tips
# https://api.foursquare.com/v2/venues/4a50f27ef964a5204bb01fe3/tips
# https://api.foursquare.com/v2/venues/571d2ced498e590d68ee74ae/tips
# https://api.foursquare.com/v2/venues/576f2c3c498e0917af14bc65/tips
# https://api.foursquare.com/v2/venues/4d977255c19fb60c42179765/tips
# https://api.foursquare.com/v2/venues/57c2080a498e1bdf3cc66019/tips
# https://api.foursquare.com/v2/venues/537803a0498ef1607aafd28b/tips
# https://api.foursquare.com/v2/venues/4c7979d8a868370436c7104d/tips
# https://api.foursquare.com/v2/venues/4fcbdcaae4b00a0e855124dd/tips
# https://api.foursquare.com/v2/venues/5359898111d27f2c30969a1c/tips
# https://api.foursquare.com/v2/venues/4a6fa830f964a520bad61fe3/tips
# https://api.foursquare.com/v2/venues/4abd01bbf964a5200a8820e3/tips
# https://api.foursquare.com/v2/venues/4b3f7adcf964a5208fa725e3/tips
# https://api.foursquare.com/v2/venues/4bf4b51e6a31d13ab025962e/tips
# https://api.foursquare.com/v2/venues/518a87b3454aef48b51a84ce/tips
# https://api.foursquare.com/v2/venues/4baac398f964a52040853ae3/tips
# https://api.foursquare.com/v2/venues/4bb1338ef964a520f0823ce3/tips
# https://api.foursquare.com/v2/venues/509aaaa46ebbda87a3c403ea/tips
# https://api.foursquare.com/v2/venues/465c3714f964a5202f471fe3/tips
# https://api.foursquare.com/v2/venues/553bf653498eba55ec0bdfde/tips
# https://api.foursquare.com/v2/venues/589800799398ab157abb6fba/tips
# https://api.foursquare.com/v2/venues/57252fc6498e11c981242555/tips
# https://api.foursquare.com/v2/venues/567a07e3498ea3d07b6a8a8f/tips
# https://api.foursquare.com/v2/venues/4e4acf1bb0fb37342ef3f2d3/tips
# https://api.foursquare.com/v2/venues/4a9453d1f964a5203d2120e3/tips
# https://api.foursquare.com/v2/venues/4f9b59bae4b04dd734c0b31c/tips
# https://api.foursquare.com/v2/venues/511ff09ce4b0655fee51b12d/tips
# https://api.foursquare.com/v2/venues/4b05e4cff964a52045e522e3/tips
# https://api.foursquare.com/v2/venues/412d2800f964a520c90c1fe3/tips
# https://api.foursquare.com/v2/venues/4aea412bf964a5208aba21e3/tips
# https://api.foursquare.com/v2/venues/42853f80f964a520f7221fe3/tips
# https://api.foursquare.com/v2/venues/4a6ce03bf964a520e5d11fe3/tips
# https://api.foursquare.com/v2/venues/49dcddddf964a520b35f1fe3/tips
# https://api.foursquare.com/v2/venues/4aa5a2d1f964a520084920e3/tips
# https://api.foursquare.com/v2/venues/43388b80f964a52031281fe3/tips
# https://api.foursquare.com/v2/venues/49cd30d4f964a520ca591fe3/tips
# https://api.foursquare.com/v2/venues/4ac95679f964a520b3bf20e3/tips
# https://api.foursquare.com/v2/venues/57ec6f49498ed271e121a819/tips
# https://api.foursquare.com/v2/venues/4a078354f964a52077731fe3/tips
# https://api.foursquare.com/v2/venues/566f6460498e99280bc37325/tips
# https://api.foursquare.com/v2/venues/4a11df1af964a52056771fe3/tips
# https://api.foursquare.com/v2/venues/49c9af8ef964a52090581fe3/tips
# https://api.foursquare.com/v2/venues/4a20c042f964a520bf7c1fe3/tips
# https://api.foursquare.com/v2/venues/49bee6d5f964a520f2541fe3/tips
# https://api.foursquare.com/v2/venues/4e9cb24446904f8f933fc63b/tips
# https://api.foursquare.com/v2/venues/4a639ce4f964a52073c51fe3/tips
# https://api.foursquare.com/v2/venues/55aed676498ea88a0e5564d7/tips
# https://api.foursquare.com/v2/venues/4a346d9bf964a5203f9c1fe3/tips
# https://api.foursquare.com/v2/venues/52422e69498e75d8a0025c58/tips
# https://api.foursquare.com/v2/venues/4b79ec82f964a520921a2fe3/tips
# https://api.foursquare.com/v2/venues/49c6b109f964a52070571fe3/tips
# https://api.foursquare.com/v2/venues/4aa7cb0ef964a5203b4d20e3/tips
# https://api.foursquare.com/v2/venues/4cf70303dc40a35dcf5e4b54/tips
# https://api.foursquare.com/v2/venues/557252af498ee891b8e13db7/tips
# https://api.foursquare.com/v2/venues/566ded46498eba26c63d7524/tips

# %%
tips_table.shape
# Out:
# (8501, 7)

# %% [markdown]
# # EDA
#
# Let's do some eda:
# 1. Look at distribution of numerical, categorical
# 2. Look at place with most number of ratings
# 3. Look at place with most visitors
# 4. Compare how long has it been around?

# %%
df.describe()
# Out:
#               lat        long  total_checkins   total_users   tip_count  \
# count  186.000000  186.000000      186.000000    186.000000  186.000000
# mean    39.044626 -100.205028     3184.532258   1871.763441   46.591398
# std      4.633716   22.815427     5846.437554   3195.694605   86.665837
# min     30.161288 -122.699762       31.000000     27.000000    1.000000
# 25%     37.746304 -122.314328      436.250000    285.250000    6.000000
# 50%     40.617080 -118.187491     1106.500000    713.500000   15.000000
# 75%     40.798864  -73.991625     3116.000000   1866.500000   42.750000
# max     47.682633  -71.053873    47260.000000  25780.000000  673.000000
#
#            rating
# count  186.000000
# mean     8.047312
# std      0.968151
# min      5.400000
# 25%      7.400000
# 50%      8.200000
# 75%      8.900000
# max      9.500000

# %%
#let's explore total_users and zoom in:

def eda_plots(feature, range_1, bins=30):
    plt.hist(feature, bins =bins )
    plt.show()
    plt.hist(feature, range = range_1, bins = bins)
    plt.show()
    plt.scatter(x = feature.index, y = feature)
    plt.show()
    
    sns.boxplot(feature)
    plt.show()
    sns.boxplot(feature, showfliers = False)

# %% [markdown]
# # Total Checkins
#
# Summary:
# - most locations are below 10,000
# - everything above 10,000 are outliers (investigate those and who they are - maybe they're super old?)
# - average is 3000
# - explore if location affects total checkins

# %%
#eda_plots(df.total_checkins, range_1 = [0,7000])

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x = df.state, y = df.total_checkins)
plt.xticks(rotation=45)

#looks like there's not much difference by state, except cali and new york have the highest variance
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %%
#let's look at these outliers

outliers = df[df.total_checkins >7000]
outliers.state.value_counts()
# Out:
# CA    10
# NY     5
# MA     3
# TX     2
# WA     2
# Name: state, dtype: int64

# %% [markdown]
# # Total Users

# %%
#eda_plots(df.total_users, range_1 = [0,5000])

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x = df.state, y = df.total_users, showfliers = False)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %% [markdown]
# # Tip Counts

# %%
#eda_plots(df.tip_count, range_1 = [0,400])

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x = df.state, y = df.tip_count, showfliers = False)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %% [markdown]
# # Ratings

# %%
eda_plots(df.rating, range_1 = [5,10], bins = 10)

# %%
plt.figure(figsize =(10,6))
plt.hist(df.rating);
plt.title("Ice Cream Rating Histogram");
plt.xlabel("Rating", font);
plt.ylabel("Frequency");

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x = df.state, y = df.rating, showfliers = False)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %%
df.groupby("state").count()
# Out:
#        venue_id  name  address  city  zipcode  lat  long  total_checkins  \
# state
# CA           72    72       72    72       72   72    72              72
# MA           21    21       21    21       21   21    21              21
# NY           52    52       52    52       52   52    52              52
# OR            8     8        8     8        8    8     8               8
# TX           17    17       17    17       17   17    17              17
# WA           16    16       16    16       16   16    16              16
#
#        total_users  tip_count  rating
# state
# CA              72         72      72
# MA              21         21      21
# NY              52         52      52
# OR               8          8       8
# TX              17         17      17
# WA              16         16      16

# %%
sns.pairplot(df)

# %%
df_corr = df[['total_checkins', 'total_users', 'tip_count', 'rating']].corr()
sns.heatmap(df_corr)

# %%
tips_table.user_gender.value_counts()
# Out:
# female    4144
# male      3629
# none       728
# Name: user_gender, dtype: int64

# %%
#  'Carmela',
#  'Cold Stone Creamery',
#  "Davey's",
#  'Emack',
#  'Full Tilt',
#  'J.P. Licks',
#  'Little Giant',
#  "Mateo's",
#  "McConnell's",
#  "Molly Moon's",
#  'Smitten',
#  'Sprinkles',
#  "Tara's Organic",
#  'Van Leeuwen']

# %% [markdown]
# # Data Cleaning

# %%
#put all tips from each place into one box
text_df = tips_table[['venue_id', 'tip_text']].groupby('venue_id')['tip_text'].apply(list)

# %%
dct_list = []
for i in range(0, text_df.shape[0]):
    dct={}
    dct['venue_id'] = text_df.index[i]
    dct['tip_text'] = " ".join(text_df[i])
    dct_list.append(dct)

text_df = pd.DataFrame(dct_list, columns = ['venue_id', 'tip_text'])

# %%
#join ratings in the dataframe
text_df = text_df.merge(df[['venue_id', 'name', 'rating']], on='venue_id', how='inner')

# %%
text_df.shape
# Out:
# (186, 4)

# %%
def replace_duplicate_venues(venue_name, text_df):
    #create a df with just the duplicates
    venue_df = text_df[text_df.name.str.contains(venue_name)].copy()
    #get the mean rating
    mean_rating = venue_df.rating.mean()
    #replace all the venue_id with the first venue_id
    venue_df['venue_id'] = venue_df.iloc[0,0]
    #do a groupby to put all the text in one row
    venue_df = venue_df.groupby('venue_id')['tip_text'].apply(list)
    #change list to string
    venue_df[0] = ''.join(venue_df[0])
    #create a dataframe
    venue_df = pd.DataFrame(venue_df)
    #add the other columns back
    venue_df['name'] = venue_name
    venue_df['rating'] = mean_rating
    #reset index
    venue_df.reset_index(inplace = True)
    #drop all duplicates from text_df 
    text_df = text_df.drop(text_df[text_df.name.str.contains(venue_name)].index, axis = 0)
    #append the new series to text_df
    text_df = text_df.append(venue_df)
    return text_df

for each in duplicate_venues:
    text_df = replace_duplicate_venues(each, text_df)

# %%
text_df.shape
# Out:
# (116, 4)

# %%
#encode y to top 25% rating is 1, else 0
text_df['rating_encoded'] = text_df['rating'].apply(lambda x: 1 if x >=8.8 else 0)

# %%
#reset index
text_df.reset_index(drop = True, inplace = True)

# %%
#set y and X
y = text_df['rating_encoded']
X = text_df.drop('rating_encoded', axis =1)

# %%
#calculate the baseline
baseline = 1-y.mean()
print('baseline', baseline)
# Out:
# baseline 0.75

# %% [markdown]
# # LDA

# %%
#LDA
#I want to know what the top 25% of shops have in common? Or what the bottom 25% have in common? 

top_performers = text_df[text_df.rating_encoded ==1].reset_index(drop = True)
middle_performers = text_df[(text_df.rating < 8.0) & (text_df.rating > 7.3)].reset_index(drop = True)
bottom_performers = text_df[text_df.rating <7.3].reset_index(drop = True)

# %%
top_performers['word_count'] = top_performers.tip_text.apply(lambda x: len(x.split(' ')))
top_performers.head()
# Out:
#                    venue_id  \
# 0  3fd66200f964a52033eb1ee3
# 1  43388b80f964a52031281fe3
# 2  43504680f964a520b2281fe3
# 3  45eaff58f964a5208e431fe3
# 4  463c53f3f964a5202d461fe3
#
#                                             tip_text  \
# 0  You will find more than just your typical flav...
# 1  Ranked the best ice cream shop in all of Massa...
# 2  Award-winning French Chef Jacques Torres opene...
# 3  Their ice cream is amazing, and the cashiers a...
# 4  Probably the creamiest ice cream I've had in t...
#
#                                                 name  rating  rating_encoded  \
# 0  The Original Chinatown Ice Cream Factory 華埠雪糕行...     9.2               1
# 1                                        Toscanini's     9.5               1
# 2                           Jacques Torres Chocolate     8.9               1
# 3                                   Bi-Rite Creamery     9.5               1
# 4                      Fentons Creamery & Restaurant     9.2               1
#
#    word_count
# 0        4933
# 1        3366
# 2        1392
# 3        7636
# 4        2855

# %%
sns.pairplot(top_performers)

# %%
def lda_model(feature, ngram_range, num_topics):
    tf = CountVectorizer(stop_words = 'english', ngram_range = (ngram_range))
    X = cvect.fit_transform(feature)
    feature_names = cvect.get_feature_names()
    lda = LatentDirichletAllocation(n_topics=num_topics)
    lda.fit(X)
    results = pd.DataFrame(lda.components_,
                      columns=feature_names)
    
    return results

def make_wordcloud(topic_results, topic_num, num_words):
    word_lst = topic_results.T[topic_num].sort_values(ascending=False).index
    word_string = ' '.join(word_lst[0:num_words])
    wordcloud = WordCloud(background_color = 'white', 
                         scale = 5).generate(word_string)
    plt.figure(figsize=(12,5))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
tp_results = lda_model(top_performers.tip_text, (2,2), 3)
mp_results = lda_model(middle_performers.tip_text, (2,2), 3)
bp_results = lda_model(bottom_performers.tip_text, (2,2), 3)
# Out:
# /Users/htn211/anaconda/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:508: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# /Users/htn211/anaconda/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:508: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# /Users/htn211/anaconda/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:508: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)

# %% [markdown]
# ### Top Performer Topics

# %%
for each in range(tp_results.shape[0]):
    make_wordcloud(tp_results, each, 25)

# %% [markdown]
# ### Bottom Performers Topics

# %%
for each in range(bp_results.shape[0]):
    make_wordcloud(bp_results, each, 25)

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 2017, stratify = y)

# %% [markdown]
# # Text Preprocessing
#
# Gotta clean!
# - add to list of stop words - add ice cream to the list
# - remove Punctuation
# - stemming/lemmatization

# %%
from string import punctuation
lst_punc = list(set(punctuation))

for line in open('stop_words_lst.txt', "r"):
    line = line.replace('"', '').strip()
    
my_stopwords = line.split(",")

#add punctuation to stop words:
[my_stopwords.append(each) for each in lst_punc]
my_stopwords.append("ice cream")

my_stopwords[-1]
# Out:
# 'ice cream'

# %%
cv = CountVectorizer(stop_words = my_stopwords, ngram_range = (2,2), strip_accents = 'ascii')
cv.fit(top_performers.tip_text)

cv_words = pd.DataFrame(cv.transform(text_df.tip_text).todense(),
                              columns=cv.get_feature_names())
print(cv_words.sum().sort_values(ascending=False).head(25))
# Out:
# ice cream            2760
# salted caramel        343
# secret breakfast      154
# waffle cone           146
# black sesame          130
# earl grey             128
# honey lavender        119
# green tea             112
# peanut butter          92
# red velvet             89
# chocolate chip         85
# soft serve             83
# cream good             79
# hot chocolate          73
# cream flavors          72
# great ice              71
# chocolate ice          71
# cream amazing          68
# ice creams             68
# vietnamese coffee      67
# unique flavors         66
# cream ve               65
# cookies cream          63
# cream delicious        61
# waffle cones           61
# dtype: int64

# %%
cv = CountVectorizer(stop_words = my_stopwords, ngram_range = (2,4))
cv.fit(bottom_performers.tip_text)

stopped_words = pd.DataFrame(cv.transform(bottom_performers.tip_text).todense(),
                              columns=cv.get_feature_names())
print(stopped_words.sum().sort_values(ascending=False).head(25))
# Out:
# ice cream             90
# soft serve             5
# unlimited toppings     5
# rolled ice             5
# rolled ice cream       5
# bing box               4
# made order             4
# milk tea               4
# earl grey              4
# young lady             4
# green tea              3
# iced tea               3
# shaved ice             3
# good ice               3
# mango bing             3
# cheese ice             3
# don order              3
# cheese ice cream       3
# good ice cream         3
# vegan ice cream        2
# grey ice               2
# cream good             2
# ice cream show         2
# earl grey ice          2
# cream excellent        2
# dtype: int64

# %% [markdown]
# # Optimization

# %%
X_train_pp = X_train.tip_text
X_test_pp = X_test.tip_text

# %%
def fit_score_gs_predict(pipe, grid, X_train, y_train, X_test, y_test):
    
    skf = StratifiedKFold(n_splits = 3, random_state = 2017)
    
    gs = GridSearchCV(pipe, grid, verbose =1, n_jobs = -1, cv = skf)
    gs.fit(X_train, y_train)
    predictions = gs.predict(X_test)
    print('best cross-val accuracy', gs.best_score_)
    print('best params', gs.best_params_)
    print('best test accuracy', gs.best_estimator_.score(X_test, y_test))
    print(confusion_matrix(y_test, predictions)) 
    print(classification_report(y_test, predictions)) 
    
    return gs.best_estimator_, predictions

# %%
#logistic regression

lr = LogisticRegression(random_state = 2017)

grid = {
    'clf__penalty': ['l1', 'l2'],
    'clf__C': np.linspace(100, 1000, 10)
}

pipe = Pipeline(
   [('tf', TfidfVectorizer(stop_words = 'english')), 
    ('trunSVD', TruncatedSVD()),
    ('clf', lr)])

lr_w_truncated_svd, lr_tsvd_predictions = \
        fit_score_gs_predict(pipe, grid, X_train_pp, y_train, X_test_pp, y_test)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    3.7s finished
# best cross-val accuracy 0.831168831169
# best params {'clf__C': 100.0, 'clf__penalty': 'l1'}
# best test accuracy 0.74358974359
# [[25  4]
#  [ 6  4]]
#              precision    recall  f1-score   support
#
#           0       0.81      0.86      0.83        29
#           1       0.50      0.40      0.44        10
#
# avg / total       0.73      0.74      0.73        39

# %%
lr = LogisticRegression(random_state = 2017, penalty = 'l1')

grid_nosvd = {
    'clf__C': [1000],
    'tf__ngram_range': [(2,2)]
}

pipe_nosvd = Pipeline(
   [('tf', TfidfVectorizer(stop_words = 'english', ngram_range = (2,2))), 
    ('clf', lr)])

lr_tf_model, lr_tf_pred = \
        fit_score_gs_predict(pipe_nosvd, grid_nosvd, X_train_pp, y_train, X_test_pp, y_test)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.4s finished
# best cross-val accuracy 0.753246753247
# best params {'clf__C': 1000, 'tf__ngram_range': (2, 2)}
# best test accuracy 0.794871794872
# [[25  4]
#  [ 4  6]]
#              precision    recall  f1-score   support
#
#           0       0.86      0.86      0.86        29
#           1       0.60      0.60      0.60        10
#
# avg / total       0.79      0.79      0.79        39

# %%
#model without truncated svd
tf = TfidfVectorizer(stop_words = 'english', ngram_range= (2,2))
lr = LogisticRegression('l1', C = 1000, random_state=2017)
X_train_tf = tf.fit_transform(X_train_pp)
X_test_tf = tf.transform(X_test_pp)

lr_model = lr.fit(X_train_tf, y_train)
predictions = lr.predict(X_test_tf)
print('mean cross val score', np.mean(cross_val_score(lr, X_train_tf, y_train, cv = 3)))
print('std cross val score', np.std(cross_val_score(lr, X_train_tf, y_train, cv = 3)))
print('test accuracy', lr.score(X_test_tf, y_test))
print(confusion_matrix(y_test, predictions)) 
print(classification_report(y_test, predictions))
# Out:
# mean cross val score 0.831604938272
# std cross val score 0.0347508386879
# test accuracy 0.794871794872
# [[25  4]
#  [ 4  6]]
#              precision    recall  f1-score   support
#
#           0       0.86      0.86      0.86        29
#           1       0.60      0.60      0.60        10
#
# avg / total       0.79      0.79      0.79        39

# %%
coef = lr.coef_

coef_df = pd.DataFrame(coef, columns = tf.get_feature_names()).T
coef_not_0 = coef_df[0][coef_df[0] !=0]
plt.hist(coef_not_0)
# Out:
# (array([  1.,   2.,  24.,   9.,   2.,   2.,   1.,   0.,   1.,   1.]),
#  array([ -31.61194627,  -17.01230357,   -2.41266087,   12.18698183,
#           26.78662452,   41.38626722,   55.98590992,   70.58555262,
#           85.18519531,   99.78483801,  114.38448071]),
#  <a list of 10 Patch objects>)

# %%
coef_not_0.shape
# Out:
# (43,)

# %%
coef_not_0.sort_values().index
# Out:
# Index(['mexican chocolate', 'red velvet', 'candied bacon', 'rolled ice',
#        'item believe', 'gelato espresso', 'delicious caffe', 'salted caramel',
#        'coffee cappuccino', 'good amaretto', 'cappuccino gelato',
#        'espresso affogato', 'caffe umbria', 'cream delicious', 'really good',
#        'black tan', 'gelato best', 'gelato delicious', 'chimney cones',
#        'waffle cone', 'milk chocolate', 'cream bar', 'rice gelato',
#        'banana split', 'mango sticky', 'coconut ice', 'black sesame',
#        'strong coffee', 'honey lavender', 'secret breakfast', 'burnt honey',
#        'chorizo caramel', 'ice cream', 'passion fruit', 'hot chocolate',
#        'sticky rice', 'worth wait', 'churros leche', 'like organic',
#        'vanilla malt', 'cream cookies', 'hot fudge', 'blood orange'],
#       dtype='object')

# %% [markdown]
# # Evaluating the Model

# %%
lr_model.coef_
# Out:
# array([[ 0.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
probability = lr_model.predict_proba(X_test_tf)
predict_proba = pd.DataFrame(probability, columns = ["0", "1"], index = X_test.name).head()

# %%
fpr, tpr, thresh = roc_curve(y_test, predictions)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=[8,8])
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc, linewidth=4)
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([-0.05, 1.0])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('Receiver operating characteristic for predicting ice cream store rating', fontsize=18)
plt.legend(loc="lower right")
plt.show()
